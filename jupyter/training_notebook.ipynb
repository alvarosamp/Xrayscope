# %%
# %pip install mlflow 'numpy<2'opencv-python scikit-learn boto3 python-dotenv requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mlflow
#   Downloading mlflow-3.1.4-py3-none-any.whl (24.7 MB)
#      |████████████████████████████████| 24.7 MB 681 kB/s eta 0:00:012     |█████████████████████▎          | 16.4 MB 2.2 MB/s eta 0:00:04
# Collecting numpy<2opencv-python
#   Downloading numpy-2.0.0-cp39-cp39-macosx_14_0_x86_64.whl (6.9 MB)
#      |████████████████████████████████| 6.9 MB 1.3 MB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp39-cp39-macosx_10_9_x86_64.whl (12.1 MB)
#      |████████████████████████████████| 12.1 MB 1.8 MB/s eta 0:00:01
# Collecting boto3
#   Downloading boto3-1.40.70-py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 3.5 MB/s eta 0:00:01
# Collecting python-dotenv
#   Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Collecting requests
#   Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.3 MB/s  eta 0:00:01
# Collecting scipy<2
#   Downloading scipy-1.13.1-cp39-cp39-macosx_10_9_x86_64.whl (39.4 MB)
#      |████████████████████████████████| 39.4 MB 3.3 MB/s eta 0:00:013
# Collecting graphene<4
#   Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 7.6 MB/s eta 0:00:01
# Collecting alembic!=1.10.0,<2
#   Downloading alembic-1.16.5-py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 9.6 MB/s eta 0:00:01
# Collecting mlflow-skinny==3.1.4
#   Downloading mlflow_skinny-3.1.4-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 7.6 MB/s eta 0:00:01
# Collecting gunicorn<24
#   Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 3.6 MB/s eta 0:00:011
# Collecting sqlalchemy<3,>=1.4.0
#   Downloading sqlalchemy-2.0.44-cp39-cp39-macosx_10_9_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 27.0 MB/s eta 0:00:01
# Collecting Flask<4
#   Downloading flask-3.1.2-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 8.2 MB/s eta 0:00:01
# Collecting docker<8,>=4.0.0
#   Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 8.9 MB/s eta 0:00:01
# Collecting pandas<3
#   Downloading pandas-2.3.3-cp39-cp39-macosx_10_9_x86_64.whl (11.6 MB)
#      |████████████████████████████████| 11.6 MB 1.8 MB/s eta 0:00:01     |█████████████████▉              | 6.5 MB 2.4 MB/s eta 0:00:03
# Collecting pyarrow<21,>=4.0.0
#   Downloading pyarrow-20.0.0-cp39-cp39-macosx_12_0_x86_64.whl (32.3 MB)
#      |████████████████████████████████| 32.3 MB 4.4 MB/s eta 0:00:01
# Collecting matplotlib<4
#   Downloading matplotlib-3.9.4-cp39-cp39-macosx_10_12_x86_64.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 1.5 MB/s eta 0:00:01
# Collecting cloudpickle<4
#   Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Collecting click<9,>=7.0
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 3.5 MB/s eta 0:00:01
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /Users/alvarosamp/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (8.7.0)
# Collecting opentelemetry-sdk<3,>=1.9.0
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 1.4 MB/s eta 0:00:01
# Collecting fastapi<1
#   Downloading fastapi-0.121.1-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 5.5 MB/s eta 0:00:01
# Collecting sqlparse<1,>=0.4.0
#   Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
#      |████████████████████████████████| 44 kB 2.8 MB/s eta 0:00:01
# Collecting protobuf<7,>=3.12.0
#   Downloading protobuf-6.33.0-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
#      |████████████████████████████████| 427 kB 3.5 MB/s eta 0:00:01
# Collecting pyyaml<7,>=5.1
#   Downloading pyyaml-6.0.3-cp39-cp39-macosx_10_13_x86_64.whl (184 kB)
#      |████████████████████████████████| 184 kB 6.8 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /Users/alvarosamp/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (4.15.0)
# Collecting uvicorn<1
#   Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 3.8 MB/s eta 0:00:011
# Collecting databricks-sdk<1,>=0.20.0
#   Downloading databricks_sdk-0.73.0-py3-none-any.whl (753 kB)
#      |████████████████████████████████| 753 kB 148 kB/s eta 0:00:01
# Requirement already satisfied: packaging<26 in /Users/alvarosamp/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==3.1.4->mlflow) (25.0)
# Collecting gitpython<4,>=3.1.9
#   Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
#      |████████████████████████████████| 208 kB 1.5 MB/s eta 0:00:01
# Collecting pydantic<3,>=1.10.8
#   Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
#      |████████████████████████████████| 463 kB 3.3 MB/s eta 0:00:01
# Collecting opentelemetry-api<3,>=1.9.0
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.4 MB/s eta 0:00:01
# Collecting cachetools<7,>=5.0.0
#   Downloading cachetools-6.2.1-py3-none-any.whl (11 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 7.7 MB/s eta 0:00:01
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting botocore<1.41.0,>=1.40.70
#   Downloading botocore-1.40.70-py3-none-any.whl (14.1 MB)
#      |████████████████████████████████| 14.1 MB 2.8 MB/s eta 0:00:01
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.15.0,>=0.14.0
#   Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 5.7 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Downloading idna-3.11-py3-none-any.whl (71 kB)
#      |████████████████████████████████| 71 kB 4.5 MB/s eta 0:00:011
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.4.4-cp39-cp39-macosx_10_9_universal2.whl (209 kB)
#      |████████████████████████████████| 209 kB 4.9 MB/s eta 0:00:01
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
#      |████████████████████████████████| 129 kB 6.7 MB/s eta 0:00:01
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.10.5-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 5.2 MB/s eta 0:00:01
# Collecting Mako
#   Downloading mako-1.3.10-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 5.2 MB/s eta 0:00:011
# Collecting tomli
#   Downloading tomli-2.3.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/alvarosamp/Library/Python/3.9/lib/python/site-packages (from botocore<1.41.0,>=1.40.70->boto3) (2.9.0.post0)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 6.6 MB/s eta 0:00:01
# Collecting google-auth~=2.0
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
#      |████████████████████████████████| 223 kB 5.6 MB/s eta 0:00:01
# Collecting starlette<0.50.0,>=0.40.0
#   Downloading starlette-0.49.3-py3-none-any.whl (74 kB)
#      |████████████████████████████████| 74 kB 3.1 MB/s eta 0:00:01
# Collecting annotated-doc>=0.0.2
#   Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Collecting itsdangerous>=2.2.0
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting markupsafe>=2.1.1
#   Downloading markupsafe-3.0.3-cp39-cp39-macosx_10_9_x86_64.whl (11 kB)
# Collecting blinker>=1.9.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting jinja2>=3.1.2
#   Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 7.1 MB/s eta 0:00:01
# Collecting werkzeug>=3.1.0
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      |████████████████████████████████| 224 kB 3.6 MB/s eta 0:00:01
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 2.1 MB/s eta 0:00:01
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 1.9 MB/s eta 0:00:01
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Collecting graphql-core<3.3,>=3.1
#   Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
#      |████████████████████████████████| 207 kB 5.6 MB/s eta 0:00:01
# Collecting graphql-relay<3.3,>=3.1
#   Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: zipp>=3.20 in /Users/alvarosamp/Library/Python/3.9/lib/python/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.1.4->mlflow) (3.23.0)
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pillow>=8
#   Downloading pillow-11.3.0-cp39-cp39-macosx_10_10_x86_64.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 833 kB/s eta 0:00:011
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl (265 kB)
#      |████████████████████████████████| 265 kB 6.9 MB/s eta 0:00:01
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 6.5 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.7-cp39-cp39-macosx_10_9_x86_64.whl (65 kB)
#      |████████████████████████████████| 65 kB 2.8 MB/s eta 0:00:011
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.1-cp39-cp39-macosx_10_9_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 4.9 MB/s eta 0:00:01
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting opentelemetry-semantic-conventions==0.59b0
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
#      |████████████████████████████████| 207 kB 7.7 MB/s eta 0:00:01
# Collecting tzdata>=2022.7
#   Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#      |████████████████████████████████| 347 kB 3.4 MB/s eta 0:00:01
# Collecting pytz>=2020.1
#   Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 5.7 MB/s eta 0:00:01
# Collecting pyasn1<0.7.0,>=0.6.1
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 3.1 MB/s  eta 0:00:01
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting pydantic-core==2.41.5
#   Downloading pydantic_core-2.41.5-cp39-cp39-macosx_10_12_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 5.1 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.70->boto3) (1.15.0)
# Collecting greenlet>=1
#   Downloading greenlet-3.2.4-cp39-cp39-macosx_11_0_universal2.whl (269 kB)
#      |████████████████████████████████| 269 kB 5.5 MB/s eta 0:00:01
# Collecting anyio<5,>=3.6.2
#   Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 5.2 MB/s eta 0:00:01
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/alvarosamp/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.6.2->starlette<0.50.0,>=0.40.0->fastapi<1->mlflow-skinny==3.1.4->mlflow) (1.3.0)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting h11>=0.8
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: sniffio, pyasn1, idna, urllib3, typing-inspection, smmap, rsa, pydantic-core, pyasn1-modules, opentelemetry-api, charset-normalizer, certifi, cachetools, anyio, annotated-types, starlette, requests, pydantic, protobuf, opentelemetry-semantic-conventions, numpy, markupsafe, jmespath, h11, greenlet, graphql-core, google-auth, gitdb, click, annotated-doc, werkzeug, uvicorn, tzdata, tomli, threadpoolctl, sqlparse, sqlalchemy, scipy, pyyaml, pytz, pyparsing, pillow, opentelemetry-sdk, Mako, kiwisolver, joblib, jinja2, itsdangerous, importlib-resources, graphql-relay, gitpython, fonttools, fastapi, databricks-sdk, cycler, contourpy, cloudpickle, botocore, blinker, scikit-learn, s3transfer, pyarrow, pandas, mlflow-skinny, matplotlib, gunicorn, graphene, Flask, docker, alembic, python-dotenv, mlflow, boto3
# Successfully installed Flask-3.1.2 Mako-1.3.10 alembic-1.16.5 annotated-doc-0.0.4 annotated-types-0.7.0 anyio-4.11.0 blinker-1.9.0 boto3-1.40.70 botocore-1.40.70 cachetools-6.2.1 certifi-2025.10.5 charset-normalizer-3.4.4 click-8.1.8 cloudpickle-3.1.2 contourpy-1.3.0 cycler-0.12.1 databricks-sdk-0.73.0 docker-7.1.0 fastapi-0.121.1 fonttools-4.60.1 gitdb-4.0.12 gitpython-3.1.45 google-auth-2.43.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 greenlet-3.2.4 gunicorn-23.0.0 h11-0.16.0 idna-3.11 importlib-resources-6.5.2 itsdangerous-2.2.0 jinja2-3.1.6 jmespath-1.0.1 joblib-1.5.2 kiwisolver-1.4.7 markupsafe-3.0.3 matplotlib-3.9.4 mlflow-3.1.4 mlflow-skinny-3.1.4 numpy-2.0.0 opentelemetry-api-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 pandas-2.3.3 pillow-11.3.0 protobuf-6.33.0 pyarrow-20.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.12.4 pydantic-core-2.41.5 pyparsing-3.2.5 python-dotenv-1.2.1 pytz-2025.2 pyyaml-6.0.3 requests-2.32.5 rsa-4.9.1 s3transfer-0.14.0 scikit-learn-1.6.1 scipy-1.13.1 smmap-5.0.2 sniffio-1.3.1 sqlalchemy-2.0.44 sqlparse-0.5.3 starlette-0.49.3 threadpoolctl-3.6.0 tomli-2.3.0 typing-inspection-0.4.2 tzdata-2025.2 urllib3-1.26.20 uvicorn-0.38.0 werkzeug-3.1.3
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_x86_64.whl (57.3 MB)
#      |████████████████████████████████| 57.3 MB 242 kB/s eta 0:00:01     |███████████████                 | 27.1 MB 1.6 MB/s eta 0:00:20
# Requirement already satisfied: numpy<2.3.0,>=2 in /Users/alvarosamp/Library/Python/3.9/lib/python/site-packages (from opencv-python) (2.0.0)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.12.0.88
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os 
import mlflow
import mlflow.sklearn
import numpy as np
import cv2
import boto3
import requests
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from dotenv import load_dotenv
import subprocess
import socket

# %%
#Configurando o ambiente
PROFILE = 'local' # Mudar para `cloud`quando for rodar na AWS`

#Variaveis para execucao na nuvem obtidas atraves do terraform 
ALB_DNS_NAME = ''# Obter com terraform output alb_dns_name
DATASOURCE_BUCKET_NAME = '' # Obter com terraform output datasource_bucket_name

# %%
#Configurando as conexoes
print('--- Configurando conexoes ---')
print(f'Profile : {PROFILE}')

if PROFILE == 'cloud':
    print('Configurando em modo cloud')
    # Validação das variáveis obrigatórias
    if not ALB_DNS_NAME or not DATASOURCE_BUCKET_NAME:
        raise ValueError("Para o profile = cloud, define:")
    # Configurando DNS primeiro (adicionando nomes nos ips)
    try:
        alb_dns = ALB_DNS_NAME
        alb_ip = socket.gethostbyname(alb_dns)
        hosts_entry = f"{alb_ip} mlflow.xrayscope.local"
        subprocess.run(['sudo', 'bash', '-c', f"echo '{hosts_entry}' >> /etc/hosts"], check=True)
        print('✅ DNS configurado com sucesso')
    except Exception as e:
        print(f'⚠️ Erro ao configurar DNS: {e}')

    # Usar o nome DNS configurado
    MLFLOW_TRACKING_URI = 'http://mlflow.xrayscope.local'
    BUCKET_NAME = DATASOURCE_BUCKET_NAME
    MLFLOW_S3_ENDPOINT_URL = None
    os.environ['AWS_DEFAULT_REGION'] = 'us-east-1'  # Ajuste conforme necessário

else:
    print('Configurando em modo local')
    try:
        # Prefer .env.local (one level up), fallback to .env.example if present
        base = os.path.abspath(os.path.join(os.getcwd(), '..'))
        env_local = os.path.join(base, '.env.local')
        env_example = os.path.join(base, '.env.example')
        if os.path.exists(env_local):
            load_dotenv(dotenv_path=env_local)
        elif os.path.exists(env_example):
            load_dotenv(dotenv_path=env_example)
        else:
            print('Aviso: nenhum .env.local ou .env.example encontrado; usando variáveis de ambiente atuais')
    except Exception as e:
        print(f'Aviso: nao foi possivel carregar o arquivo de ambiente: {e}')

    EXECUTION_ENV = os.getenv('EXECUTION_ENVIRONMENT', 'local')
    # Fix: when EXECUTION_ENV is 'local' we want localhost endpoints
    if EXECUTION_ENV == 'local':
        MLFLOW_TRACKING_URI = os.getenv('MLFLOW_TRACKING_URI', 'http://localhost:5000')
        BUCKET_NAME = os.getenv('BUCKET_NAME', 'datasource')
        MLFLOW_S3_ENDPOINT_URL = os.getenv('MLFLOW_S3_ENDPOINT_URL', 'http://localhost:9000')
        AWS_ACCESS_KEY_ID = os.getenv('AWS_ACCESS_KEY_ID')
        AWS_SECRET_ACCESS_KEY = os.getenv('AWS_SECRET_ACCESS_KEY')
        if MLFLOW_S3_ENDPOINT_URL: os.environ['MLFLOW_S3_ENDPOINT_URL'] = MLFLOW_S3_ENDPOINT_URL
        if AWS_ACCESS_KEY_ID: os.environ['AWS_ACCESS_KEY_ID'] = AWS_ACCESS_KEY_ID
        if AWS_SECRET_ACCESS_KEY: os.environ['AWS_SECRET_ACCESS_KEY'] = AWS_SECRET_ACCESS_KEY
    else:
        # cloud or other execution env: try to read from env variables (or fallbacks)
        MLFLOW_TRACKING_URI = os.getenv('MLFLOW_TRACKING_URI', 'http://mlflow.xrayscope.local')
        BUCKET_NAME = os.getenv('BUCKET_NAME', DATASOURCE_BUCKET_NAME if 'DATASOURCE_BUCKET_NAME' in globals() else 'datasource')

# Ensure var is set for downstream code
os.environ['MLFLOW_TRACKING_URI'] = MLFLOW_TRACKING_URI
print(f'MLFLOW_TRACKING_URI: {MLFLOW_TRACKING_URI}')
print(f'BUCKET_NAME: {BUCKET_NAME}')



print('--------')
# Out:
# --- Configurando conexoes ---
# Profile : local
# Configurando em modo local
# MLFLOW_TRACKING_URI: http://mlflow:5000
# BUCKET_NAME: datasource
# --------

# %%
def load_images_from_s3_folder(s3_client, bucket_name, prefix, label, img_size):
    print(f"Carregando imagens de: {prefix}...")
    images = []
    response = s3_client.list_objects_v2(Bucket=bucket_name, Prefix=prefix)
    if 'Contents' not in response: return images
    for obj in response['Contents']:
        key = obj['Key']
        if key.endswith(('.jpeg', '.jpg', '.png')):
            image_data = s3_client.get_object(Bucket=bucket_name, Key=key)['Body'].read()
            nparr = np.frombuffer(image_data, np.uint8)
            img = cv2.imdecode(nparr, cv2.IMREAD_GRAYSCALE)
            img_resized = cv2.resize(img, img_size)
            images.append((img_resized.flatten(), label))
    print(f"-> {len(images)} imagens carregadas.")
    return images

def load_data_from_minio(s3_client, bucket_name, img_size):
    print("\n--- Etapa de Carregamento de Dados ---")
    data_normal = load_images_from_s3_folder(s3_client, bucket_name, "NORMAL/", 0, img_size)
    data_pneumonia = load_images_from_s3_folder(s3_client, bucket_name, "PNEUMONIA/", 1, img_size)
    all_data = data_normal + data_pneumonia
    if not all_data: raise ValueError("Nenhuma imagem foi carregada.")
    np.random.shuffle(all_data)
    X = np.array([item[0] for item in all_data])
    y = np.array([item[1] for item in all_data])
    print("--- Dados carregados e prontos para o treinamento ---")
    return X, y

# %%
try:
    if PROFILE == "cloud" or (PROFILE == "local" and os.getenv("EXECUTION_ENVIRONMENT") == "cloud"):
        s3 = boto3.client("s3")
    else:
        s3 = boto3.client("s3", endpoint_url=os.getenv("MLFLOW_S3_ENDPOINT_URL"))
    
    X_data, y_data = load_data_from_minio(s3, bucket_name=BUCKET_NAME, img_size=(64, 64))
    X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2, random_state=42, stratify=y_data)
    
    print("\n--- Treinando a próxima Versão do Modelo ---")
    model_v2 = RandomForestClassifier(n_estimators=150, random_state=42)
    model_v2.fit(X_train, y_train)
    accuracy = accuracy_score(y_test, model_v2.predict(X_test))
    print(f"Modelo v2 treinado. Acurácia: {accuracy:.4f}")
    
    print("\n--- Registrando no MLflow ---")
    MODEL_NAME = "RandomForest"
    
    experiment_name = "SageMaker_Experiments" if PROFILE == "cloud" else "Notebook_Experiments"
    mlflow.set_experiment(experiment_name)
    client = mlflow.tracking.MlflowClient()

    with mlflow.start_run(run_name=f"Training_{PROFILE}_RandomForest_v2") as run:
        mlflow.log_param("n_estimators", 150)
        mlflow.log_param("environment", PROFILE)
        mlflow.log_metric("accuracy", accuracy)
        
        model_info = mlflow.sklearn.log_model(
            sk_model=model_v2,
            artifact_path="model-files",
            registered_model_name=MODEL_NAME
        )
        
        print(f"\n✅ SUCESSO! Modelo '{MODEL_NAME}' registrado como versão {model_info.registered_model_version}.")
        
        print(f"Promovendo a versão {model_info.registered_model_version} para 'Production'...")
        client.transition_model_version_stage(
            name=MODEL_NAME,
            version=model_info.registered_model_version,
            stage="Production",
            archive_existing_versions=True
        )
        print("✅ Versão promovida com sucesso!")
        
        if PROFILE == "cloud":
            print("🌐 MLflow UI configurado")
            print("🎯 O webapp já está usando o novo modelo automaticamente!")
        else:
            print("Acesse a UI do MLflow para confirmar as alterações: http://localhost:5000")

except Exception as e:
    print(f"\n❌ FALHA! Algo deu errado.")
    print(f"   Detalhe do erro: {e}")
    import traceback
    traceback.print_exc()
